# %%
from langchain_community.llms import Ollama

llm = Ollama(model="llama3")
print(llm.invoke("Suggest a fancy Indian restaurant name"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 from langchain_community.llms import Ollama
#       3 llm = Ollama(model="llama3")
# ----> 4 print(llm.invoke("Suggest a fancy Indian restaurant name"))
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\llms.py:378, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     367 @override
#     368 def invoke(
#     369     self,
#    (...)    374     **kwargs: Any,
#     375 ) -> str:
#     376     config = ensure_config(config)
#     377     return (
# --> 378         self.generate_prompt(
#     379             [self._convert_input(input)],
#     380             stop=stop,
#     381             callbacks=config.get("callbacks"),
#     382             tags=config.get("tags"),
#     383             metadata=config.get("metadata"),
# ...

# %%
import sys
# !{sys.executable} -m pip install -U langchain-huggingface
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
